# %%
Title: Customer Segmentation using Machine Learning

Problem:
Businesses need to understand customer behavior to improve sales and marketing strategies.

Dataset:
Mall Customer Dataset (contains Age, Gender, Income, Spending Score)

Algorithm:
K-Means Clustering

Steps:
1. Data preprocessing
2. Feature selection
3. Apply K-Means
4. Visualize clusters

Expected Output:
- Customer groups based on spending habits
- Graph showing clusters
- Insights for marketing strategies

Conclusion:
Helps businesses target the right customers effectively.
# Out:
#   Cell In[1], line 1
#     Title: Customer Segmentation using Machine Learning
#                     ^
# SyntaxError: invalid syntax
