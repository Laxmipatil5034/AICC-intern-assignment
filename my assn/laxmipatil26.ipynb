# %%
# Import library
import pandas as pd

# Step 1: Create a raw dataset with issues
data = {
    "Name": ["Alice", "Bob", "alice", None, "David", "Bob"],
    "Age": [20, 21, 20, 22, None, 21],
    "Department": ["CS", "IT", "cs", "ECE", "IT", "IT"]
}

df = pd.DataFrame(data)

print("Original Dataset:\n")
print(df)

# Step 2: Handle missing values
df["Name"].fillna("Unknown", inplace=True)
df["Age"].fillna(df["Age"].mean(), inplace=True)

# Step 3: Remove duplicates
df.drop_duplicates(inplace=True)

# Step 4: Standardize text (make lowercase)
df["Name"] = df["Name"].str.lower()
df["Department"] = df["Department"].str.upper()

print("\nCleaned Dataset:\n")
print(df)
# Out:
# Original Dataset:
#
#     Name   Age Department
# 0  Alice  20.0         CS
# 1    Bob  21.0         IT
# 2  alice  20.0         cs
# 3   None  22.0        ECE
# 4  David   NaN         IT
# 5    Bob  21.0         IT
#
# Cleaned Dataset:
#
#       Name   Age Department
# 0    alice  20.0         CS
# 1      bob  21.0         IT
# 2    alice  20.0         CS
# 3  unknown  22.0        ECE
# 4    david  20.8         IT
# C:\Users\patil\AppData\Local\Temp\ipykernel_13700\3401062651.py:17: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Name"].fillna("Unknown", inplace=True)
# C:\Users\patil\AppData\Local\Temp\ipykernel_13700\3401062651.py:18: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Age"].fillna(df["Age"].mean(), inplace=True)
