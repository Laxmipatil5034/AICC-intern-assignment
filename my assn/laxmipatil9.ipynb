# %%
# Assignment: AI Around Me
# List of 10 real-life AI applications with ML explanation

ai_applications = [
    ("Google Maps",
     "Uses machine learning to predict traffic and suggest fastest routes based on past and real-time data."),
    
    ("YouTube Recommendations",
     "ML algorithms analyze your watch history and preferences to recommend videos."),
    
    ("Voice Assistants (Alexa/Google Assistant)",
     "Uses speech recognition and NLP models to understand and respond to voice commands."),
    
    ("Email Spam Filter",
     "ML models classify emails as spam or not based on patterns and previous data."),
    
    ("Online Shopping (Amazon/Flipkart)",
     "Recommender systems suggest products based on your browsing and purchase history."),
    
    ("Face Unlock in Mobile",
     "Uses computer vision and deep learning to recognize and verify your face."),
    
    ("Chatbots",
     "Uses natural language processing (NLP) to understand queries and provide responses."),
    
    ("Netflix Recommendations",
     "ML models suggest movies and shows based on your viewing habits."),
    
    ("Google Search",
     "Uses ranking algorithms and ML to provide relevant search results."),
    
    ("Bank Fraud Detection",
     "ML models detect unusual transaction patterns to prevent fraud.")
]

# Display the applications
print("AI Around Me - Real-Life Applications:\n")

for i, (app, explanation) in enumerate(ai_applications, start=1):
    print(f"{i}. {app}: {explanation}")
# Out:
# AI Around Me - Real-Life Applications:
#
# 1. Google Maps: Uses machine learning to predict traffic and suggest fastest routes based on past and real-time data.
# 2. YouTube Recommendations: ML algorithms analyze your watch history and preferences to recommend videos.
# 3. Voice Assistants (Alexa/Google Assistant): Uses speech recognition and NLP models to understand and respond to voice commands.
# 4. Email Spam Filter: ML models classify emails as spam or not based on patterns and previous data.
# 5. Online Shopping (Amazon/Flipkart): Recommender systems suggest products based on your browsing and purchase history.
# 6. Face Unlock in Mobile: Uses computer vision and deep learning to recognize and verify your face.
# 7. Chatbots: Uses natural language processing (NLP) to understand queries and provide responses.
# 8. Netflix Recommendations: ML models suggest movies and shows based on your viewing habits.
# ...
